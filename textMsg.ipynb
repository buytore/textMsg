# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 


df = pd.read_csv('textDataSheet1.csv')
# df.PHONE.unique()

msgGroups = '([0-9])'
df['NUM MSG'] = df['NBR MSG'].str.extract(two_groups, expand=True)
df['DATE'] = pd.to_datetime(df['DATE'], format='%m/%d/%Y  %H:%M:%S')
df['NUM MSG'] = pd.to_numeric(df['NUM MSG'], downcast='signed')
df
# Out:
#                    DATE                                     TXT MSG  \
# 0   2016-12-28 21:43:00               Text Msg - Sent: 403-369-2288
# 1   2016-12-29 20:19:00  Picture Messaging - Pictures: 807-220-2646
# 2   2016-12-29 20:20:00  Picture Messaging - Pictures: 807-220-5276
# 3   2016-12-29 07:23:00           Text Msg - Received: 403-369-2288
# 4   2016-12-29 07:32:00               Text Msg - Sent: 807-220-2646
# 5   2016-12-29 07:44:00           Text Msg - Received: 807-220-2646
# 6   2016-12-29 12:50:00           Text Msg - Received: 403-464-1525
# 7   2016-12-29 16:09:00               Text Msg - Sent: 403-464-1525
# 8   2016-12-29 16:31:00           Text Msg - Received: 403-464-1525
# 9   2016-12-30 07:50:00           Text Msg - Received: 807-220-5276
# 10  2016-12-30 10:00:00           Text Msg - Received: 403-993-3660
# 11  2016-12-30 10:00:00               Text Msg - Sent: 403-993-3660
# 12  2016-12-30 11:00:00               Text Msg - Sent: 403-993-3660
# ...

# %%
df['PHONE'].value_counts()
# Out:
# 403-620-7964    131
# 403-464-1525    114
# 403-669-4192     98
# 807-220-2646     29
# 403-829-3633     19
# 403-993-3660     18
# 403-585-4820     14
# 807-220-3771     13
# 807-220-5276     12
# 905-714-6820      9
# 403-803-0919      8
# 403-554-7418      5
# 403-690-6469      5
# 403-680-8343      4
# 403-831-9542      4
# 403-809-8757      4
# 403-999-5309      4
# 587-229-7876      4
# 403-399-7014      3
# 403-850-2995      2
# 403-650-2114      2
# 403-369-2288      2
# 226-455-1406      1
# 226-270-3802      1
# 807-220-2454      1
# 587-401-2500      1
# l-Roll@dryde      1
# 807-938-8150      1
# 403-991-2628      1
# 807-938-8188      1
# 403-614-3110      1
# 403-519-5363      1
# 807-221-8141      1
# eived: 34522      1
# 587-436-0307      1
# 403-370-0554      1
# 807-220-0670      1
# 807-220-0660      1
# 403-815-8474      1
# Name: PHONE, dtype: int64

# %%
df.loc[df['PHONE'] == '403-829-3633']
# Out:
#                    DATE                            TXT MSG         PHONE  \
# 161 2017-01-24 20:38:00                       403-829-3633  403-829-3633
# 166 2017-01-24 21:49:00      Text Msg - Sent: 403-829-3633  403-829-3633
# 204 2017-01-30 11:00:00      Text Msg - Sent: 403-829-3633  403-829-3633
# 205 2017-01-30 11:00:00  Text Msg - Received: 403-829-3633  403-829-3633
# 233 2017-02-04 13:00:00  Text Msg - Received: 403-829-3633  403-829-3633
# 234 2017-02-04 13:00:00      Text Msg - Sent: 403-829-3633  403-829-3633
# 318 2017-02-13 16:00:00      Text Msg - Sent: 403-829-3633  403-829-3633
# 319 2017-02-13 17:00:00  Text Msg - Received: 403-829-3633  403-829-3633
# 320 2017-02-13 17:06:00      Text Msg - Sent: 403-829-3633  403-829-3633
# 322 2017-02-14 09:36:00  Text Msg - Received: 403-829-3633  403-829-3633
# 323 2017-02-14 10:08:00      Text Msg - Sent: 403-829-3633  403-829-3633
# 324 2017-02-14 10:59:00  Text Msg - Received: 403-829-3633  403-829-3633
# ...

# %%
df1 = df

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts

# %%
s1 = df1['PHONE'].value_counts()
s1.plot(grid=True)

# %%
df1[150:200].plot.line()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=120, facecolor='w', edgecolor='k')
df1.groupby(['PHONE'])['NUM MSG'].sum().plot(rot=90, fontsize=6)
#s2.plot(rot=90, fontsize=6)

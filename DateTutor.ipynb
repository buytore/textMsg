# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame, Panel
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
ao1 = np.loadtxt('monthly.ao.index.b50.current.ascii.txt')

#ao = pd.read_table('monthly.ao.index.b50.current.ascii.txt', delim_whitespace=True)

# %%
ao1
# Out:
# array([[  1.95000000e+03,   1.00000000e+00,  -6.03100000e-02],
#        [  1.95000000e+03,   2.00000000e+00,   6.26810000e-01],
#        [  1.95000000e+03,   3.00000000e+00,  -8.12750000e-03],
#        ...,
#        [  2.01600000e+03,   1.20000000e+01,   1.78640000e+00],
#        [  2.01700000e+03,   1.00000000e+00,   9.41970000e-01],
#        [  2.01700000e+03,   2.00000000e+00,   3.39860000e-01]])

# %%
dates = pd.date_range('1950-01', '2017-03', freq='M')

# %%
AO = Series(ao1[:,2], index=dates)
plt.figure(num=None, figsize=(8, 6), dpi=100, facecolor='w', edgecolor='k')
AO['1979':'1999'].plot()

# %%
plt.figure(num=None, figsize=(8, 6), dpi=100, facecolor='w', edgecolor='k')
AO['1980-05':'1981-03'].plot()
